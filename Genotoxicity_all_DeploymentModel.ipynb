# %% [markdown]
# <a href="https://colab.research.google.com/github/stawiskm/QSAR_Modelbuilding_amesTest/blob/main/Genotoxicity_all_DeploymentModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Ames test [Part 1] Descriptor Calculation and Dataset Preparation**
#
# Marc Jermann
#
# In this Jupyter notebook, we will be building a real-life **data science project**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be calculating molecular descriptors that are essentially quantitative description of the compounds in the dataset. Finally, we will be preparing this into a dataset for subsequent model building in Part 2.
#
# **with all available data**
#
# ---

# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2022-05-18 22:09:05--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2022-05-18 22:09:05--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  --.-KB/s    in 0.1s
#
# 2022-05-18 22:09:05 (165 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# --2022-05-18 22:09:06--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2022-05-18 22:09:06--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh’
#
# padel.sh            100%[===================>]     231  --.-KB/s    in 0s
#
# 2022-05-18 22:09:06 (15.3 MB/s) - ‘padel.sh’ saved [231/231]

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
#   inflating: __MACOSX/PaDEL-Descriptor/._config
#   inflating: PaDEL-Descriptor/PubchemFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._PubchemFingerprinter.xml
#   inflating: PaDEL-Descriptor/ExtendedFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._ExtendedFingerprinter.xml
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprinter.xml
#   inflating: PaDEL-Descriptor/GraphOnlyFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._GraphOnlyFingerprinter.xml
#   inflating: PaDEL-Descriptor/SubstructureFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprinter.xml
#   inflating: PaDEL-Descriptor/Descriptors.xls
#   inflating: __MACOSX/PaDEL-Descriptor/._Descriptors.xls
#    creating: PaDEL-Descriptor/lib/
#   inflating: __MACOSX/PaDEL-Descriptor/._lib
#   inflating: PaDEL-Descriptor/PaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/._PaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/SubstructureFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprintCount.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprintCount.xml
#   inflating: PaDEL-Descriptor/descriptors.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._descriptors.xml
#   inflating: PaDEL-Descriptor/license/lgpl-2.1.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl-2.1.txt
#   inflating: PaDEL-Descriptor/license/LICENSE.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._LICENSE.txt
#   inflating: PaDEL-Descriptor/license/README - CDK
#   inflating: __MACOSX/PaDEL-Descriptor/license/._README - CDK
#   inflating: PaDEL-Descriptor/license/lgpl.license
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl.license
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL.jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(4).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(2).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1(1).jar
#   inflating: PaDEL-Descriptor/lib/swing-worker-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._swing-worker-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(3).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(5).jar
#   inflating: PaDEL-Descriptor/lib/jama(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(1).jar
#   inflating: PaDEL-Descriptor/lib/appframework-1.0.3.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._appframework-1.0.3.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(7).jar
#   inflating: PaDEL-Descriptor/lib/vecmath1.2-1.14.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._vecmath1.2-1.14.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(6).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(2).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(4).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(5).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(2).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(3).jar
#   inflating: PaDEL-Descriptor/lib/jama(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(7).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(1).jar
#   inflating: PaDEL-Descriptor/lib/jama(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(3).jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all(1).jar
#   inflating: PaDEL-Descriptor/lib/jama.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama.jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all.jar
#   inflating: PaDEL-Descriptor/lib/jama(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(5).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(7).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(4).jar
#   inflating: PaDEL-Descriptor/lib/cdk-1.4.15.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._cdk-1.4.15.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(6).jar
#   inflating: PaDEL-Descriptor/lib/jama(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(1).jar
#   inflating: PaDEL-Descriptor/lib/guava-17.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._guava-17.0.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(5).jar

# %% [markdown]
# ## **Load bioactivity data**

# %% [markdown]
# Download the curated ChEMBL bioactivity data that has been pre-processed from Parts 1 and 2 of this Bioinformatics Project series. Here we will be using the **bioactivity_data_3class_pIC50.csv** file that essentially contain the pIC50 values that we will be using for building a regression model.

# %%
import pandas as pd

# %%
# CHEMBL data
df1 = pd.read_csv("https://raw.githubusercontent.com/stawiskm/QSAR_Modelbuilding_amesTest/main/data/QSAR_ames_raw-data.csv")
df1 = df1.drop(labels=['molecule_chembl_id'],axis=1)
df1.columns = ['canonical_smiles', 'class']

# %%
df1
# Out:
#                                       canonical_smiles      class
# 0    CC(C)(N)C(=O)N[C@H](COCc1ccccc1)c1nnnn1CCOC(=O...  Non-toxic
# 1    C=C1C(=O)O[C@@H]2C[C@@]3(C)CCCC(=C)[C@@H]3C[C@...      Toxic
# 2    C=C1CCC[C@]2(C)C[C@H]3OC(=O)[C@@H](C)[C@H]3C[C...  Non-toxic
# 3                                     O=c1ccc2ccccc2o1  Non-toxic
# 4                            COc1c2ccoc2cc2oc(=O)ccc12  Non-toxic
# ..                                                 ...        ...
# 650  COCCCOc1cc2c(cc1OC)-c1cc(=O)c(C(=O)O)cn1[C@H](...  Non-toxic
# 651           N#C/C(=C\c1cccc2cnccc12)c1c[nH]c2ccccc12  Non-toxic
# 652  O=c1cc(NC2CCN(S(=O)(=O)C(F)(F)F)CC2)c2cc(C(c3c...  Non-toxic
# 653    N#Cc1cnc2ccc(-c3c(-c4ccc(F)c(Cl)c4)ncn3CCO)nn12  Non-toxic
# 654  CC(C)(C)OC(=O)Nc1ccc(-c2cc(C(=O)NCCc3cc(C(=O)N...  Non-toxic
#
# [655 rows x 2 columns]

# %%
df2 = pd.read_csv('https://github.com/stawiskm/QSAR_Modelbuilding_amesTest/raw/main/data/paperData1.csv')
df3 = pd.read_csv('https://github.com/stawiskm/QSAR_Modelbuilding_amesTest/raw/main/data/paperData2.csv')
df2.columns = ['canonical_smiles', 'class']
df3.columns = ['canonical_smiles', 'class']
df2['class'] = df2['class'].replace({'non-mutagens':'Non-toxic'})
df2['class'] = df2['class'].replace({'mutagens':'Toxic'})
df3['class'] = df3['class'].replace({'non-mutagens':'Non-toxic'})
df3['class'] = df3['class'].replace({'mutagens':'Toxic'})

# %%
df_all = pd.concat([df1,df2,df3], axis=0)

# %%
def cleanSMILES(row):
    cpd = str(row.canonical_smiles).split('.')
    cpd_longest = max(cpd, key = len)
    return cpd_longest

# %%
df_all['smiles'] = df_all.apply(cleanSMILES ,axis=1)
df_all = df_all.drop("canonical_smiles",axis=1)
df_all = df_all.rename({"smiles":"canonical_smiles"},axis=1)

df_all=df_all.drop_duplicates(subset=['canonical_smiles'], keep='last')

# %%
selection = ["canonical_smiles","class"]
df_all[selection].to_csv('molecule.smi', sep='\t', index=False, header=False)

# %% [markdown]
# ## **Calculate fingerprint descriptors**

# %% [markdown]
# ### **Calculate PaDEL descriptors**

# %%
6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5856/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5857/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5858/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5859/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5860/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5861/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5862/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5863/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5864/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5865/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5866/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5867/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5868/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5869/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5870/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5871/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5872/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5873/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5874/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5875/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5876/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5877/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5878/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5879/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5881/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5880/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5883/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5882/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5884/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5886/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5885/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5887/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5889/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5888/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5890/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5891/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5892/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5893/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5894/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5895/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5896/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5897/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5898/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5899/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5901/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5900/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5903/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5902/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5904/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5905/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5906/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5907/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5908/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5909/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5910/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5911/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5912/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5913/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5914/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5915/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5916/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5917/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5918/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5919/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5920/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5921/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5922/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5923/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5924/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5925/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5926/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5927/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5928/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5929/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5930/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5931/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5932/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5933/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5934/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5935/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5936/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5937/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5938/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5939/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5940/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5941/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5942/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5943/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5944/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5945/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5946/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5947/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5949/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5948/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5951/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5950/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5953/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5952/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5955/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5954/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5956/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5957/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5958/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5959/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5961/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5960/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5963/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5962/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5964/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5966/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5965/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5967/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5968/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5969/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5970/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5971/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5972/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5973/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5974/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5975/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5977/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5976/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5978/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5979/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5980/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5981/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5982/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5983/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5984/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5985/6041). Average speed: 0.13 s/mol.
# Processing Toxic in molecule.smi (5986/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5987/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5988/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5989/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5991/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5990/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5992/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5993/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5994/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5995/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5996/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5997/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5998/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6000/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (5999/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6001/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6002/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6004/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6003/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6005/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6007/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6006/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6008/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6009/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6010/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6011/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6013/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6012/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6015/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6014/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6016/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6017/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6018/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6019/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6020/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6022/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6021/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6024/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6023/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6026/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6025/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6027/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6029/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6028/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6031/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6030/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6032/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6034/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6033/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6035/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6036/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6037/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6038/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6039/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6041/6041). Average speed: 0.13 s/mol.
# Processing Non-toxic in molecule.smi (6040/6041). Average speed: 0.13 s/mol.
# Descriptor calculation completed in 12 mins 35.455 secs . Average speed: 0.13 s/mol.

# %%
df = pd.read_csv('descriptors_output.csv')
df = df.rename({'Name': 'class'}, axis='columns')
df.to_csv('QSAR_DescriptorData_ALL.csv', index=False)

# %% [markdown]
# ## Final Model for deployment

# %%
import pickle
import pandas as pd
from lightgbm import LGBMClassifier

# %%
df = pd.read_csv("https://raw.githubusercontent.com/stawiskm/QSAR_Modelbuilding_amesTest/main/data/QSAR_DescriptorData_ALL.csv")

# %%
X = df.drop(['class'], axis=1)
y = df["class"]

# %%
clfmodel = {'boosting_type': 'gbdt', 'learning_rate': 0.126, 'max_depth': 21, 'n_estimators': 96, 'num_leaves': 32, 'subsample_for_bin': 60000}

model =  LGBMClassifier(boosting_type=clfmodel["boosting_type"],
                        learning_rate=clfmodel['learning_rate'],
                        n_estimators=clfmodel['n_estimators'],
                        num_leaves=clfmodel['num_leaves'],
                        subsample_for_bin=clfmodel["subsample_for_bin"],
                        max_depth=clfmodel["max_depth"],
                        random_state=42)

model.fit(X,y)

pickle.dump(model, open('amesTest_model.pkl', 'wb'))

# %%
model_reloaded = pickle.load(open("amesTest_model.pkl", 'rb'))
model_reloaded.predict(X)
# Out:
# array(['Non-toxic', 'Non-toxic', 'Non-toxic', ..., 'Non-toxic',
#        'Non-toxic', 'Non-toxic'], dtype=object)
